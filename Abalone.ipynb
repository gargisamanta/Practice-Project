# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
abalone=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # The rings of each abalone  will lead us to the age of that abalone.

# %%
abalone.shape # Total no.of rows and columns
# Out:
# (4177, 9)

# %%
abalone.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
abalone.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
abalone.info()# Only Sex is having categorical data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# # EDA

# %%
abalone.isnull().sum() # To see if any missing values are there or not
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
abalone.corr() # All features are positively correlated
# Also length and diameter are highly correlated
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(abalone.corr(),annot=True)
plt.show()

# %% [markdown]
# # Let's do some plotting to know how the data columns are distributed in the dataset (Data Visualization)

# %%
fig = plt.figure(figsize = (10,5))
sns.barplot(x = 'Rings', y = 'Length', data = abalone)
plt.show()
# With increase in length the rings also increases

# %%
plt.figure(figsize=(16,8))
plt.scatter(abalone['Length'],abalone['Rings'], c='m')
plt.xlabel('Length of Abalone (mm)')
plt.ylabel('Number of rings')
plt.show()
# # Clearly shows  with increase in length the rings also increases

# %%
fig = plt.figure(figsize = (10,5))
sns.barplot(x = 'Rings', y = 'Diameter', data = abalone)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(abalone['Diameter'],abalone['Rings'], c='m')
plt.xlabel('Diameter')
plt.ylabel('Number of rings')
plt.show()
# # Clearly shows  with increase in length the rings also increases

# %%
fig = plt.figure(figsize = (10,5))
sns.barplot(x = 'Rings', y = 'Height', data = abalone)
plt.show()
# With increase in length the rings also increases

# %%
plt.figure(figsize=(16,8))
plt.scatter(abalone['Height'],abalone['Rings'], c='r')
plt.xlabel('Height')
plt.ylabel('Number of rings')
plt.show()
# With increase in diameter the rings also increases ,showing two outliers

# %%
fig = plt.figure(figsize = (10,5))
sns.barplot(x = 'Rings', y = 'Whole weight', data = abalone)
plt.show()
# With increase in length the rings also increases

# %%
plt.figure(figsize=(16,8))
plt.scatter(abalone['Whole weight'],abalone['Rings'], c='b')
plt.xlabel('Whole weight of Abalone')
plt.ylabel('Number of rings')
plt.show()

# %%
fig = plt.figure(figsize = (10,5))
sns.barplot(x = 'Rings', y = 'Shucked weight', data = abalone)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(abalone['Shucked weight'],abalone['Rings'], c='black')
plt.xlabel('Shucked weight of Abalone')
plt.ylabel('Number of rings')
plt.show()

# %%
fig = plt.figure(figsize = (10,5))
sns.barplot(x = 'Rings', y = 'Viscera weight', data = abalone)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(abalone['Viscera weight'],abalone['Rings'], c='r')
plt.xlabel('Viscera weight')
plt.ylabel('Number of rings')
plt.show()

# %%
fig = plt.figure(figsize = (10,5))
sns.barplot(x = 'Rings', y = 'Shell weight', data = abalone)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(abalone['Shell weight'],abalone['Rings'], c='y')
plt.xlabel('Shell weight')
plt.ylabel('Number of rings')
plt.show()

# %%
# Plotting  pairwise to visualize the relationship  among the features in  the dataset

plt.figure(figsize=(12,10))

sns.pairplot(abalone)
plt.show()

# %% [markdown]
# # Its clearly visible that all features are linearrly correlated

# %% [markdown]
# # As sex feature is categorical in nature so it needs to be changed into numerical value

# %%
abalone=pd.get_dummies(abalone)
abalone
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
# ...

# %% [markdown]
# # Splitting of data

# %%
abalone.shape
# Out:
# (4177, 11)

# %%
from sklearn.model_selection import train_test_split

# %%
#split dataset
training_set= abalone.iloc[:4099, :]
validation_set= abalone.iloc[4099:, :]
print(training_set.shape)
print(validation_set.shape)
# Out:
# (4099, 11)
# (78, 11)

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
x= training_set[['Length','Height']]
y= training_set['Rings'].values.reshape(-1,1)

x_val= validation_set[['Length','Height']]
y_val= validation_set['Rings'].values.reshape(-1,1)

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.1,random_state=42)

# %%
lin_reg = LinearRegression()

lin_reg.fit(x_train,y_train)

#test RMSE
lin_reg_pred = lin_reg.predict(x_test)
test_rmse = mean_squared_error(y_test, lin_reg_pred, squared= False)
print(f'Test RMSE: {test_rmse}')
# Out:
# Test RMSE: 2.5679099174951547

# %%
#validation RMSE
lin_reg_pred_val = lin_reg.predict(x_val)
val_rmse = mean_squared_error(y_val, lin_reg_pred_val, squared= False)
print(f'validation RMSE: {val_rmse}')
# Out:
# validation RMSE: 1.5661783782311605

# %% [markdown]
# # Regularization Model

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
ridge= Ridge()
parameters = {'alpha': [-15, -10, -8, -4, -3, -2, 1, 5, 10, 20]}

ridge_regressor =GridSearchCV(ridge, parameters, scoring='neg_root_mean_squared_error', cv=5)
ridge_regressor.fit(x_train, y_train)

print(ridge_regressor.best_params_)
print(-ridge_regressor.best_score_)
# Out:
# {'alpha': 1}
# 2.656456365844888

# %%
ridge_reg= Ridge(alpha=1)
ridge_reg.fit(x_train, y_train)
ridge_reg_pred = ridge_reg.predict(x_test)

# test RMSE
test_rmse = mean_squared_error(y_test, ridge_reg_pred, squared= False)
print(f'Test RMSE: {test_rmse}')
# Out:
# Test RMSE: 2.58713000971083

# %%
#validation RMSE
ridge_reg_pred_val = ridge_reg.predict(x_val)
val_rmse = mean_squared_error(y_val, ridge_reg_pred_val, squared= False)
print(f'validation RMSE: {val_rmse}')
# Out:
# validation RMSE: 1.5640813253014862

# %%
# Lasso Modelling

# %%
lasso= Lasso(tol=0.05)
parameters = {'alpha': [-15, -10, -8, -4, -3, -2, 1, 5, 10, 20]}

lasso_regressor =GridSearchCV(lasso, parameters, scoring='neg_root_mean_squared_error', cv=5)
lasso_regressor.fit(x_train, y_train)

print(lasso_regressor.best_params_)
print(-lasso_regressor.best_score_)
# Out:
# {'alpha': 1}
# 3.242740213798146

# %%
lasso_reg= Lasso(alpha=1)
lasso_reg.fit(x_train, y_train)
lasso_reg_pred = lasso_reg.predict(x_test)

# test RMSE
test_rmse = mean_squared_error(y_test, lasso_reg_pred, squared= False)
print(f'Test RMSE: {test_rmse}')


#validation RMSE
lasso_reg_pred_val = lasso_reg.predict(x_val)
val_rmse = mean_squared_error(y_val, lasso_reg_pred_val, squared= False)
print(f'validation RMSE: {val_rmse}')
# Out:
# Test RMSE: 3.2315518915511485
# validation RMSE: 1.8892343923959762

# %% [markdown]
# # Ranfom Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
x= training_set.drop(['Diameter','Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight', 'Rings'],axis=1)
y= training_set['Rings'].values.reshape(-1,1)

x_val= validation_set.drop(['Diameter','Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight', 'Rings'],axis=1)
y_val= validation_set['Rings'].values.reshape(-1,1)

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.1,random_state=42)

# %%
rf= RandomForestRegressor()
parameters = {'n_estimators':[int(x) for x in np.linspace(100,1000,10)]}
rf_regressor= GridSearchCV(rf, parameters, scoring='neg_mean_squared_error')
rf_regressor.fit(x_train, y_train.ravel())
print(rf_regressor.best_params_)
print(-rf_regressor.best_score_)
# Out:
# {'n_estimators': 900}
# 8.38709427112215

# %%
rf_reg= RandomForestRegressor(n_estimators=400)
rf_reg.fit(x_train, y_train.ravel())
rf_reg_pred = rf_reg.predict(x_test)

# test RMSE
test_rmse = mean_squared_error(y_test, rf_reg_pred, squared= False)
print(f'Test RMSE: {test_rmse}')


#validation RMSE
rf_reg_pred_val = rf_reg.predict(x_val)
val_rmse = mean_squared_error(y_val, rf_reg_pred_val, squared= False)
print(f'validation RMSE: {val_rmse}')
# Out:
# Test RMSE: 2.6482394468400794
# validation RMSE: 2.244812555278185

# %%
rmse_compilation= {'model':['linear regression', 'ridge regression','lasso','random forest'],
    'RMSE':[1.5661783782311613, 1.5640813253014878, 1.8892343923959762, 2.2407752883529457,]}
rmse_df=pd.DataFrame(data=rmse_compilation)
rmse_df.sort_values(by=['RMSE'], ascending=False)
# Out:
#                model      RMSE
# 3      random forest  2.240775
# 2              lasso  1.889234
# 0  linear regression  1.566178
# 1   ridge regression  1.564081

# %%
# from this we can conclude ridge regression is best model

# %%
import pickle

# %%
filename= 'Abalone age prediction'
pickle.dump(ridge_reg, open(filename,'wb'))
